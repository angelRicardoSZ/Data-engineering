# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/Programming/Pz/Data_analysis_python_pandas"
# Out:
# /content/drive/MyDrive/Programming/Pz/Data_analysis_python_pandas

# %%
# !ls
# Out:
# Dataframes.ipynb  readCSV.ipynb

# %%
# !mkdir /content/drive/MyDrive/Programming/Pz/Data_analysis_python_pandas/db

# %%
# !ls
# Out:
# Dataframes.ipynb  db  readCSV.ipynb

# %%
dir_pandas ="/content/drive/MyDrive/Programming/Pz/Data_analysis_python_pandas/db/{}".format("test.csv")
dir_pandas
# Out:
# '/content/drive/MyDrive/Programming/Pz/Data_analysis_python_pandas/db/test.csv'

# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '1.3.5'

# %%
dict_data = {
    'edad' :     [ 10, 9, 13, 14, 12, 11, 12],
    'cm' : [ 115, 110, 130, 155, 125, 120, 125],
    'pais' :    [ 'co', 'mx', 'co', 'mx', 'mx', 'ch', 'ch'],
    'genero' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'Q1' : [ 5, 10, 8, np.nan, 7, 8, 3],
    'Q2' : [ 7, 9, 9, 8, 8, 8, 9.]
}
dict_data
# Out:
# {'Q1': [5, 10, 8, nan, 7, 8, 3],
#  'Q2': [7, 9, 9, 8, 8, 8, 9.0],
#  'cm': [115, 110, 130, 155, 125, 120, 125],
#  'edad': [10, 9, 13, 14, 12, 11, 12],
#  'genero': ['M', 'F', 'F', 'M', 'M', 'M', 'F'],
#  'pais': ['co', 'mx', 'co', 'mx', 'mx', 'ch', 'ch']}

# %%
df = pd.DataFrame(dict_data)
df
# Out:
#    edad   cm pais genero    Q1   Q2
# 0    10  115   co      M   5.0  7.0
# 1     9  110   mx      F  10.0  9.0
# 2    13  130   co      F   8.0  9.0
# 3    14  155   mx      M   NaN  8.0
# 4    12  125   mx      M   7.0  8.0
# 5    11  120   ch      M   8.0  8.0
# 6    12  125   ch      F   3.0  9.0

# %%
dir_pandas ="/content/drive/MyDrive/Programming/Pz/Data_analysis_python_pandas/db/{}".format("test.csv")
dir_pandas
# Out:
# '/content/drive/MyDrive/Programming/Pz/Data_analysis_python_pandas/db/test.csv'

# %%
df.to_csv(dir_pandas,index = False)

# %%
# !ls /content/drive/MyDrive/Programming/Pz/Data_analysis_python_pandas/db/
# Out:
# test.csv

# %%
df_read = pd.read_csv("/content/drive/MyDrive/Programming/Pz/Data_analysis_python_pandas/db/test.csv", sep = "|")
df_read
# Out:
#    edad   cm pais genero    Q1   Q2
# 0    10  115   co      M   5.0  7.0
# 1     9  110   mx      F  10.0  9.0
# 2    13  130   co      F   8.0  9.0
# 3    14  155   mx      M   NaN  8.0
# 4    12  125   mx      M   7.0  8.0
# 5    11  120   ch      M   8.0  8.0
# 6    12  125   ch      F   3.0  9.0

# %%
df.to_csv(dir_pandas,sep= "|",index = False)

# %%
dir_pandas = "/content/drive/MyDrive/Programming/Pz/Data_analysis_python_pandas/db/{}"
dir_pandas
# Out:
# '/content/drive/MyDrive/Programming/Pz/Data_analysis_python_pandas/db/{}'

# %%
df.to_excel(dir_pandas.format("test.xlsx"), index=False, sheet_name="Hoja_1")
# !ls /content/drive/MyDrive/Programming/Pz/Data_analysis_python_pandas/db/
# Out:
# test.csv  test.xlsx

# %%
pd.read_excel(dir_pandas.format("test.xlsx"))
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
df.to_json(dir_pandas.format("test.json"))

# %%
pd.read_json(dir_pandas.format("test.json"))
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
df.to_pickle(dir_pandas.format("test.pkl"))

# %%
pd.read_pickle(dir_pandas.format("test.pkl"))
# Out:
#    edad   cm pais genero    Q1   Q2
# 0    10  115   co      M   5.0  7.0
# 1     9  110   mx      F  10.0  9.0
# 2    13  130   co      F   8.0  9.0
# 3    14  155   mx      M   NaN  8.0
# 4    12  125   mx      M   7.0  8.0
# 5    11  120   ch      M   8.0  8.0
# 6    12  125   ch      F   3.0  9.0

# %%
df.to_parquet(dir_pandas.format("test.parquet"))

# %%
df.to_hdf(dir_pandas.format("test.hdf"), key="data", format="table")
